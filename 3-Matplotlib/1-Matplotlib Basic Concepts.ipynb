# %% [markdown]
# # Matplotlib
#
# **Collab Link:<a href="https://colab.research.google.com/drive/1XsRIsL3iobaufjvauzsDK08BOyCt2j3f?usp=sharing">Link</a>**

# %% [markdown]
# ## Introduction

# %% [markdown]
# Matplotlib is the "grandfather" library of data visualization with Python. It was created by John Hunter.
#
# * Most Popular plotting library for python
# * Control over every aspect of the figure
# * Similar to Matlab’s graphical plotting
# * So if you happen to be familiar with matlab, matplotlib will feel natural to you.
# * Goes well with numpy and pandas
#
# It is an excellent 2D and 3D graphics library for generating scientific figures.
#
# Before continuing this lecture, I encourage you just to explore the official Matplotlib web page: http://matplotlib.org/
#
# Let's learn how to use it!
#
#
# ## Installation
#
# You'll need to install matplotlib first with either:
#
#     conda install matplotlib
# or
#     pip install matplotlib
#
# ## Importing
#
# Import the `matplotlib.pyplot` module under the name `plt` (the tidy way):

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %% [markdown]
# That line is only for jupyter notebooks, if you are using another editor, you'll use: **plt.show()** at the end of all your plotting commands to have the figure pop up in another window.

# %% [markdown]
# Let's walk through a very simple example using two numpy arrays. You can also use lists, but most likely you'll be passing numpy arrays or pandas columns (which essentially also behave like arrays).
#
# **The data we want to plot:**

# %%
import numpy as np
import pandas as pd

# %%
x = np.linspace(0, 5, 11)

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y = x ** 2
z = x ** 3

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
z
# Out:
# array([  0.   ,   0.125,   1.   ,   3.375,   8.   ,  15.625,  27.   ,
#         42.875,  64.   ,  91.125, 125.   ])

# %% [markdown]
# ## Basic Matplotlib Commands

# %%
plt.plot(x, y)

# %%
plt.plot(x, z, 'g') # 'g' is color green
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.title('Title')
plt.show()

# %% [markdown]
# ## Creating Multiplots on Same Canvas

# %%
# plt.subplot(nrows, ncols, plot_num)
ax1 = plt.subplot(1, 2, 1)
ax1.plot(x, y, 'r')
ax2 = plt.subplot(1, 2, 2)
ax2.plot(x, z, 'g')

# %% [markdown]
# # Matplotlib Object Oriented Method
# Now that we've seen the basics, let's break it all down with a more formal introduction of Matplotlib's Object Oriented API. This means we will instantiate figure objects and then call methods or attributes from that object.

# %%
# Create Figure
fig = plt.figure()
# Add axes
axes = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # add_axes([left, bottom, width, height])
# Plot on the axes
axes.plot(x, y, 'b')
axes.set_xlabel('X')
axes.set_ylabel('X squared')
axes.set_title('Square Plot')
# Notice the set_ in the methods
# Out:
# Text(0.5, 1.0, 'Square Plot')

# %%
fig = plt.figure()
# Larger Axis
ax1 = fig.add_axes([0.1, 0.1, 0.8, 0.8])
ax1.plot(x, y)
# Smaller Axis
ax2 = fig.add_axes([0.2, 0.5, 0.3, 0.2])
ax2.plot(x, z)

# %% [markdown]
# ## subplots()
#
# Use similar to plt.figure() except use tuple unpacking to grab fig and axes

# %%
fig, axes = plt.subplots(2, 2)
axes[0][0].plot(x, y, 'y')
axes[0][0].set_xlabel('X')
axes[0][0].set_ylabel('X square')
axes[0][1].plot(y, x, 'r')
axes[0][1].set_xlabel('X square')
axes[0][1].set_ylabel('X')
axes[1][0].plot(x, z, 'b')
axes[1][0].set_xlabel('X')
axes[1][0].set_ylabel('X cube')
axes[1][1].plot(z, x, 'g')
axes[1][1].set_xlabel('X cube')
axes[1][1].set_ylabel('X')
plt.tight_layout()

# %% [markdown]
# fig.tight_layout() or plt.tight_layout() method automatically adjusts the positions of the axes on the figure canvas so that there is no overlapping content

# %% [markdown]
# ## legends

# %%
fig, axes = plt.subplots(figsize=(12, 5), dpi=100)
axes.plot(x, y, label="x square")
axes.plot(x, z, label="x cube")
axes.legend()

# %% [markdown]
# **figsize** is a tuple of the width and height of the figure in inches
#
# **dpi** is the dots-per-inch (pixel per inch).

# %%
# ax.legend(loc=1) upper right corner
# ax.legend(loc=2) upper left corner
# ax.legend(loc=3) lower left corner
# ax.legend(loc=4) lower right corner

# %% [markdown]
# many more options are available
#
# Most common to choose

# %%
# ax.legend(loc=0) let matplotlib decide the optimal location

# %% [markdown]
# ## Setting colors, linewidths, linetypes
#
# Matplotlib gives you *a lot* of options for customizing colors, linewidths, and linetypes.

# %%
fig, ax = plt.subplots()
# alpha arguement indicates opacity
ax.plot(x, x+1, color="blue", alpha=0.5) # half-transparant
ax.plot(x, x, color="blue", alpha=1) # opaque
ax.plot(x, x+2, color="#8B008B")        # RGB hex code
ax.plot(x, x+3, color="#FF8C00")        # RGB hex code

# %%
fig, axes = plt.subplots(figsize=(12, 6))
# linewidth or lw
axes.plot(x, x+1, color='green', linewidth=1)
axes.plot(x, x+2, color='green', linewidth=2)
axes.plot(x, x+3, color='green', linewidth=3)
# linestyle or ls (-, -., :)
axes.plot(x, x+4, color='red', lw=2, ls='--')
axes.plot(x, x+5, color='red', lw=2, ls='-.')
axes.plot(x, x+6, color='red', lw=2, ls=':')
# custom dash
line, = axes.plot(x, x+7, color='black', lw=2)
line.set_dashes([5, 10, 15, 10])
# marker  ('+', '*', 's', 'o', ',', '.', '1', '2', '3', '4', ........)
axes.plot(x, x+8, color='blue', lw=2, marker='s',markersize=10, markeredgewidth=5, markeredgecolor='red', markerfacecolor='yellow')
axes.plot(x, x+9, color='blue', lw=2, marker='o')
axes.plot(x, x+10, color='blue', lw=2, marker='1', markersize=10)
axes.plot(x, x+11, color='blue', lw=2, marker='+')

# %% [markdown]
# ## Plot Range

# %% [markdown]
# We can configure the ranges of the axes using the `set_ylim` and `set_xlim` methods in the axis object, or `axis('tight')` for automatically getting "tightly fitted" axes ranges:

# %%
fig, axes = plt.subplots(1, 3, figsize=(8, 4))

axes[0].plot(x, x**2, x, x**3)
axes[0].set_title("default axes ranges")

axes[1].plot(x, x**2, x, x**3)
axes[1].axis('tight')
axes[1].set_title("tight axes")

axes[2].plot(x, x**2, x, x**3)
axes[2].set_ylim([0, 60])
axes[2].set_xlim([2, 5])
axes[2].set_title("custom axes range");

# %% [markdown]
# # Special Plot Types
# There are many specialized plots we can create, such as barplots, histograms, scatter plots, and much more.
# Here are a few examples of these type of plots:

# %%
plt.scatter(x, y)

# %%
from random import sample
data = sample(range(1, 1000), 10)
plt.hist(data)
# Out:
# (array([2., 1., 0., 1., 0., 1., 1., 1., 0., 3.]),
#  array([ 19. , 100.1, 181.2, 262.3, 343.4, 424.5, 505.6, 586.7, 667.8,
#         748.9, 830. ]),
#  <a list of 10 Patch objects>)

# %%
data = [np.random.normal(0, std, 100) for std in range(1, 4)]
plt.boxplot(data, vert=True, patch_artist=True)
# Out:
# {'boxes': [<matplotlib.patches.PathPatch at 0x7fd2ef21c240>,
#   <matplotlib.patches.PathPatch at 0x7fd2ef27bef0>,
#   <matplotlib.patches.PathPatch at 0x7fd2ef2134e0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fd2ef21c400>,
#   <matplotlib.lines.Line2D at 0x7fd2ef27b978>,
#   <matplotlib.lines.Line2D at 0x7fd2ef283780>,
#   <matplotlib.lines.Line2D at 0x7fd2ef283748>,
#   <matplotlib.lines.Line2D at 0x7fd2ef2747f0>,
#   <matplotlib.lines.Line2D at 0x7fd2ef274198>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fd2ef27b780>,
#   <matplotlib.lines.Line2D at 0x7fd2ef22e2b0>,
#   <matplotlib.lines.Line2D at 0x7fd2ef7174a8>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7fd2ef27bcf8>,
#   <matplotlib.lines.Line2D at 0x7fd2ef22e128>,
#   <matplotlib.lines.Line2D at 0x7fd2ef274080>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7fd2ef21cb00>,
#   <matplotlib.lines.Line2D at 0x7fd2ef21ccc0>,
#   <matplotlib.lines.Line2D at 0x7fd2ef283f98>,
#   <matplotlib.lines.Line2D at 0x7fd2ef283ac8>,
#   <matplotlib.lines.Line2D at 0x7fd2ef2132b0>,
#   <matplotlib.lines.Line2D at 0x7fd2ef274e48>]}

# %% [markdown]
# We will see more on such plots in **seaborn**, a statistical plotting library for Python.

# %% [markdown]
# ## Important Links

# %% [markdown]
# * http://www.matplotlib.org - The project web page for matplotlib.
# * https://github.com/matplotlib/matplotlib - The source code for matplotlib.
# * http://matplotlib.org/gallery.html - A large gallery showcaseing various types of plots matplotlib can create. Highly recommended!
# * http://www.loria.fr/~rougier/teaching/matplotlib - A good matplotlib tutorial.
# * http://scipy-lectures.github.io/matplotlib/matplotlib.html - Another good matplotlib reference.
